# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
import numpy as np

# %%
cand = pd.read_csv("candidates_with_pokes_applications.csv")
cand = cand.dropna()

# %%
options = cand['primary_keyword'].unique()
options = options[options!='Lead']
options = np.insert(options,0,'')
options = np.sort(options)
options
# Out:
# array(['', '.NET', 'Android', 'Artist', 'Business Analyst', 'C++',
#        'Data Analyst', 'Data Engineer', 'Data Science', 'Design',
#        'DevOps', 'Flutter', 'Golang', 'HR', 'Java', 'JavaScript',
#        'Lead Generation', 'Marketing', 'Node.js', 'Other', 'PHP',
#        'Product Manager', 'Project Manager', 'Python', 'QA',
#        'QA Automation', 'Recruiter', 'Ruby', 'Rust', 'SEO', 'SQL',
#        'Sales', 'Salesforce', 'Scala', 'Scrum Master', 'Security',
#        'Support', 'Sysadmin', 'Technical Writing', 'Unity', 'iOS'],
#       dtype=object)

# %%
 def one_list(data, keyword=''):
        a = data 
        if keyword: 
            a = data[data['primary_keyword'] == keyword]
        pivoted = a.pivot_table(values = 'count', index = 'first_message', columns = 'experience', aggfunc = 'sum', fill_value=0)
        df= pivoted.reset_index().set_index('first_message')

        cols = ['no experience','1+ year', '2+ years', '3+ years', '5+ years', '7+years']
        df = df[cols]
            
        return df

# %%
df = one_list(cand, 'Lead')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 df = one_list(cand, 'Lead')
#
# Cell In [9], line 9, in one_list(data, keyword)
#       6 df= pivoted.reset_index().set_index('first_message')
#       8 cols = ['no experience','1+ year', '2+ years', '3+ years', '5+ years', '7+years']
# ----> 9 df = df[cols]
#      11 return df
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df
# Out:
# experience     no experience  1+ year  2+ years  3+ years  5+ years  7+years
# first_message
# apply                     79       77        73        90        50       45
# poke                      33       75        90       104        89       73

# %%
df.loc["apply"].sum()
df.loc["poke"].sum()
# Out:
# 414

# %%
# variables for tick labes  
a = (df.max().max()+5)
b = round(a/3, -1).astype(int)


# number of variable
categories=list(df)
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([b, b*2, b*3], color="grey", size=7)
plt.ylim(0,a)

# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't make a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df.loc["apply"].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', color = 'orange', label="Candidates with applications")
ax.fill(angles, values, 'orange', alpha=0.1)
 
# Ind2
values=df.loc["poke"].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid',color = 'green', label="Candidates with propositions")
ax.fill(angles, values, 'green', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Show the graph
plt.show()
